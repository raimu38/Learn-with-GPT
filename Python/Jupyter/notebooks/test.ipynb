# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('input.jpg')  # 適当な画像を notebooks/ に置いておく
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img)
plt.title("Input Image")

plt.show()
